# %% [markdown]
# # A. Data Exploration

# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Sentinel 1 radar data and Sentinel 2 multispectral data
#
# Source: Copernicus Browser or in Google Earth Engine

# %% [markdown]
# ## 2. Specific Marker Wadden data
#
# Source: [Rijkswaterstaat](https://open.rijkswaterstaat.nl/@254169/datarapportage-kima-overzicht-meetdata/)

# %% [markdown]
# ## 3a. Airborne LiDAR data from AHN5
#
# Source: [Actueel Hoogtebestand Nederland (Current Elevation File Netherlands)](https://www.ahn.nl/dataroom)
#
# [GeoTiles TU Delft](https://geotiles.citg.tudelft.nl/)
#
# <div style="color:red">
# Data collection date: 2023
# </div>

# %% [markdown]
# ![Screenshot of data source](images/Screenshot%202025-09-11%20191855.jpg)

# %%
import laspy

laz_files = [
    "data/AHN5/2023_C_20BZ1.LAZ",
    "data/AHN5/2023_C_20BZ2.LAZ",
    "data/AHN5/2023_C_20DN1.LAZ",
    "data/AHN5/2023_C_20DN2.LAZ"
]

def sample_laz(filepath, num_to_sample=None, chunk_size=1_000_000, random_state=None):
    """
    Sample up to `num_to_sample` points from a LAZ/LAS file without loading the entire file.
    Returns (x, y, z) numpy arrays of sampled coordinates.

    If num_to_sample is None, uses global `num_points` if defined, otherwise 100_000.
    """
    if num_to_sample is None:
        num_to_sample = globals().get("num_points", 100_000)

    with laspy.open(filepath) as f:
        total_points = int(f.header.point_count)
        if total_points == 0:
            raise RuntimeError(f"No points in file: {filepath}")

        num_to_sample = min(int(num_to_sample), total_points)

        rng = np.random.default_rng(random_state)
        sample_idx = rng.choice(total_points, size=num_to_sample, replace=False)
        sample_idx.sort()

        xs_chunks = []
        ys_chunks = []
        zs_chunks = []

        offset = 0
        collected = 0

        for chunk in f.chunk_iterator(chunk_size):
            chunk_len = len(chunk.x)
            if chunk_len == 0:
                offset += chunk_len
                continue

            mask = (sample_idx >= offset) & (sample_idx < offset + chunk_len)
            if mask.any():
                local_idx = sample_idx[mask] - offset
                xs_chunks.append(chunk.x[local_idx])
                ys_chunks.append(chunk.y[local_idx])
                zs_chunks.append(chunk.z[local_idx])
                collected += local_idx.size

                if collected >= num_to_sample:
                    break

            offset += chunk_len

        if collected == 0:
            raise RuntimeError("No sample points were collected; check file and sampling logic.")

        x = np.concatenate(xs_chunks)
        y = np.concatenate(ys_chunks)
        z = np.concatenate(zs_chunks)

    return x, y, z

# Sample points from all LAZ files
num_points = 200_000  # Total number of points to sample across all files
points_per_file = num_points // len(laz_files)
x_list, y_list, z_list = [], [], []
for laz_file in laz_files:
    x_chunk, y_chunk, z_chunk = sample_laz(laz_file, num_to_sample=points_per_file, random_state=42)
    x_list.append(x_chunk)
    y_list.append(y_chunk)
    z_list.append(z_chunk)
x = np.concatenate(x_list)
y = np.concatenate(y_list)
z = np.concatenate(z_list)
# Print some basic information
print(f"Sampled {len(x)} points from {len(laz_files)} LAZ files.")
print(f"X range: {x.min()} - {x.max()}")
print(f"Y range: {y.min()} - {y.max()}")
print(f"Z range: {z.min()} - {z.max()}")
# Out:
# Sampled 200000 points from 4 LAZ files.
# X range: 151523.747 - 159999.94
# Y range: 506250.017 - 518749.876
# Z range: -5.498 - 23.135

# %%
# 2D scatter of point cloud (X, Y) with Z shown as color
# Uses existing sampled arrays: x, y, z

fig2, ax2 = plt.subplots(figsize=(10, 8))
sc = ax2.scatter(x, y, c=z, s=1, cmap='viridis', alpha=0.8, linewidths=0)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Point cloud projection (X, Y) colored by Z')
ax2.set_aspect('equal', adjustable='box')
cbar = fig2.colorbar(sc, ax=ax2, fraction=0.046, pad=0.04)
cbar.set_label('Z (m)')
plt.show()

# %%
# Crop data to a region of interest (optional)
# Define bounding box (min_x, max_x, min_y, max_y)
min_x, max_x = 152000, 157000
min_y, max_y = 508000, 514000
bbox = (min_x, max_x, min_y, max_y)
# Filter points within bounding box
mask = (x >= min_x) & (x <= max_x) & (y >= min_y) & (y <= max_y)
x = x[mask]
y = y[mask]
z = z[mask]
# Print some basic information
print(f"Filtered to {len(x)} points within bounding box {bbox}.")
# Out:
# Filtered to 96258 points within bounding box (152000, 157000, 508000, 514000).

# %%
# 2D scatter of point cloud (X, Y) with Z shown as color
# Uses existing sampled arrays: x, y, z

fig2, ax2 = plt.subplots(figsize=(10, 8))
sc = ax2.scatter(x, y, c=z, s=1, cmap='viridis', alpha=0.8, linewidths=0)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Point cloud projection (X, Y) colored by Z')
ax2.set_aspect('equal', adjustable='box')
cbar = fig2.colorbar(sc, ax=ax2, fraction=0.046, pad=0.04)
cbar.set_label('Z (m)')
plt.show()

# %% [markdown]
# ## 3b. Aerial photos from BN
#
#
# Source: [Beeldmateriaal Nederland (Image material Netherlands)](https://www.beeldmateriaal.nl/) | [Data Portal](https://basisdata.nl/hwh-portal/download/index.html)
#
# [GeoTiles TU Delft](https://geotiles.citg.tudelft.nl/)
#
# <div style="color:red">
# Data collection date: Spring flight 2025
# </div>

# %% [markdown]
# ![GeoJSON data preview showing polygon footprints and metadata for aerial imagery tiles](images/Screenshot%202025-09-13%20091626.jpg)

# %%
import geopandas as gpd
from pathlib import Path

geojson_path = "data/BN_spring_2021/selectie_b4b10ed2-7286-4972-8079-cb7124ccef2a.geojson"
gdf = gpd.read_file(geojson_path)

# Plot footprints
ax = gdf.plot(edgecolor="black", figsize=(10, 8))
ax.set_title("Aerial Image Footprints")
ax.set_aspect("equal")

# List referenced image files from the GeoJSON properties
if "file" in gdf.columns:
    print("Referenced image files:")
    print(gdf["file"].dropna().tolist())
else:
    print("No 'file' column found in GeoJSON properties.")
# Out:
# Referenced image files:
# ['https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_158000_513000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_515000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_514000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_514000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_155000_514000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_514000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_515000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_515000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_512000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_513000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_158000_513000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_513000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_513000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_158000_513000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_512000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_158000_512000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_512000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_158000_512000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_158000_512000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_511000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_511000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_511000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_510000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_510000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_510000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_509000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_509000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_509000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_509000_RGB_hrl.tif.aux.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_156000_509000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_157000_509000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_153000_509000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_152000_510000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_152000_510000_RGB_hrl.tif.xml', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/beelden_tif_tegels/2021_152000_511000_RGB_hrl.tif', 'https://fsn1.your-objectstorage.com/hwh-ortho/2021/1/08/bee ...

# %%
gdf.head()
# Out:
#                                                 file      size  \
# 0  https://fsn1.your-objectstorage.com/hwh-ortho/...       596
# 1  https://fsn1.your-objectstorage.com/hwh-ortho/...  19933359
# 2  https://fsn1.your-objectstorage.com/hwh-ortho/...       596
# 3  https://fsn1.your-objectstorage.com/hwh-ortho/...  20690787
# 4  https://fsn1.your-objectstorage.com/hwh-ortho/...  20730269
#
#                              mtime  \
# 0 2025-03-19 14:19:58.233000+00:00
# 1 2025-03-19 14:19:56.870000+00:00
# 2 2025-03-19 14:19:56.728000+00:00
# 3 2025-03-19 14:19:58.079000+00:00
# 4 2025-03-19 14:19:54.879000+00:00
#
#                                               sha256  \
# 0  dc62d5018adf1559070841663b754bbf02d19f4eb61ca6...
# 1  0b97e7f28db541d20d5bb0ae32c10badacb49a9a8eea52...
# 2  dc62d5018adf1559070841663b754bbf02d19f4eb61ca6...
# 3  8929fb7c05e55200d3b1e405df759568cab1585c1d23e3...
# 4  4aaf7636e23b690a23077d7b9eaa396325f4c707816270...
#
#                                             geometry
# 0  POLYGON ((159000 512000, 159000 513000, 158000...
# 1  POLYGON ((157000 514000, 157000 515000, 156000...
# 2  POLYGON ((158000 513000, 158000 514000, 157000...
# 3  POLYGON ((158000 513000, 158000 514000, 157000...
# 4  POLYGON ((156000 513000, 156000 514000, 155000...

# %%
from PIL import Image
import matplotlib.pyplot as plt
from pathlib import Path

image_filename = Path(gdf["file"].dropna().iloc[5]).name
local_folder = Path("data/BN Imagerial Data/hwh-ortho/2025/Ortho/1/8/beelden_RGB_jpeg_tegels")
local_image_path = local_folder / image_filename

try:
    img = Image.open(local_image_path)
    # Reduce resolution (resize to max 2000x2000, keeping aspect ratio)
    max_size = (200, 200)
    img.thumbnail(max_size, Image.LANCZOS)
    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    plt.title(f"Aerial Image: {local_image_path} (resized)")
    plt.axis('off')
    plt.show()
except Exception as e:
    print(f"Error loading image {local_image_path}: {e}")
# Out:
# Error loading image data\BN Imagerial Data\hwh-ortho\2025\Ortho\1\8\beelden_RGB_jpeg_tegels\2023_156000_509000_RGB_hrl.tif: [Errno 2] No such file or directory: 'D:\\GitHub\\coastal-analysis-shoreline-evolution\\data\\BN Imagerial Data\\hwh-ortho\\2025\\Ortho\\1\\8\\beelden_RGB_jpeg_tegels\\2023_156000_509000_RGB_hrl.tif'

# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from pathlib import Path

fig, ax = plt.subplots(figsize=(12, 12))
local_folder = Path("data/BN Imagerial Data/hwh-ortho/2025/Ortho/1/8/beelden_RGB_jpeg_tegels")

for idx, row in gdf.iterrows():
    image_filename = Path(str(row["file"])).name
    if not image_filename.lower().endswith((".tif", ".tiff")):
        continue
    local_image_path = local_folder / image_filename
    try:
        with rasterio.open(local_image_path) as src:
            # Try to use overview, else manually downsample
            if src.overviews(1):
                ovr = src.overviews(1)[-1]
                img = src.read(
                    out_shape=(
                        src.count,
                        int(src.height // ovr),
                        int(src.width // ovr)
                    ),
                    resampling=rasterio.enums.Resampling.nearest
                )
            else:
                # Downsample entire image to max 500x500 pixels
                scale = max(src.width / 500, src.height / 500, 1)
                img = src.read(
                    out_shape=(
                        src.count,
                        int(src.height // scale),
                        int(src.width // scale)
                    ),
                    resampling=rasterio.enums.Resampling.nearest
                )
            show(img, transform=src.transform, ax=ax)
    except Exception as e:
        print(f"Error loading image {local_image_path}: {e}")

gdf.boundary.plot(ax=ax, edgecolor="black", linewidth=0.5)
ax.set_title("All aerial images (downsampled) overlaid at their geolocations")
ax.set_aspect("equal")
plt.axis('off')
plt.show()

# %%
from rasterio.transform import from_bounds
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from pathlib import Path

fig, ax = plt.subplots(figsize=(12, 12))
max_size = 500  # target max pixels on longest side

# 2025 data
# local_folder = Path("data/BN_spring_2025/hwh-ortho/2025/Ortho/1/8/beelden_RGB_jpeg_tegels")

# 2023 data
# local_folder = Path("data/BN_spring_2023/hwh-ortho/2023/Ortho/1/08/beelden_tif_tegels")

# 2021 data
local_folder = Path("data/BN_spring_2021/hwh-ortho/2021/1/08/beelden_tif_tegels")

for idx, row in gdf.iterrows():
    image_filename = Path(str(row["file"])).name
    if not image_filename.lower().endswith((".tif", ".tiff")):
        continue
    local_image_path = local_folder / image_filename
    try:
        with rasterio.open(local_image_path) as src:
            # choose overview or compute scale
            if src.overviews(1):
                ovr = src.overviews(1)[-1]
                out_height = max(1, int(src.height // ovr))
                out_width = max(1, int(src.width // ovr))
            else:
                scale = max(src.width / max_size, src.height / max_size, 1.0)
                out_width = max(1, int(src.width / scale))
                out_height = max(1, int(src.height / scale))

            img = src.read(
                out_shape=(src.count, out_height, out_width),
                resampling=rasterio.enums.Resampling.nearest
            )

            # Stretch the downsampled image to exactly fill the geometry bounds
            minx, miny, maxx, maxy = row["geometry"].bounds
            new_transform = from_bounds(minx, miny, maxx, maxy, out_width, out_height)

            show(img, transform=new_transform, ax=ax, title=image_filename)
    except Exception as e:
        print(f"Error loading image {local_image_path}: {e}")

gdf.boundary.plot(ax=ax, edgecolor="black", linewidth=0.5)
ax.set_title("All aerial images (stretched to grid cells) overlaid at their geolocations")
ax.set_aspect("equal")
plt.axis('on')
plt.show()

# %% [markdown]
# ## 4. High resolution satellite imagery
#
# Source: [Netherlands Space Office (NSO) Satellite Data Portal](https://www.satellietdataportaal.nl/)

# %% [markdown]
# ## 5. Google Earth Engine

# %%
import ee
ee.Authenticate()
# Out:
# True

# %%
# Initialize without forcing a specific GCP project to avoid permission issues.
# Use the authenticated account's default project/credentials.
try:
	ee.Initialize()
except Exception as e:
	# If initialization still fails, the user likely needs to run ee.Authenticate()
	# or be granted IAM permissions for the intended GCP project.
	print("ee.Initialize() failed:", e)
	print("If you need to use a specific GCP project, ensure your account has the required IAM role,")
	print("or run ee.Authenticate() and then retry ee.Initialize().")
	raise

print(ee.String('Hello from the Earth Engine servers!').getInfo())
# Out:
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_7TDKVSyKvBdmMqW?ref=4i2o6
# Hello from the Earth Engine servers!

# %%
# Load a Landsat image.
img = ee.Image('LANDSAT/LT05/C02/T1_L2/LT05_034033_20000913')

# Print image object WITHOUT call to getInfo(); prints serialized request instructions.
print(img)

# Print image object WITH call to getInfo(); prints image metadata.
print(img.getInfo())
# Out:
# ee.Image({
#   "functionInvocationValue": {
#     "functionName": "Image.load",
#     "arguments": {
#       "id": {
#         "constantValue": "LANDSAT/LT05/C02/T1_L2/LT05_034033_20000913"
#       }
#     }
#   }
# })
# {'type': 'Image', 'bands': [{'id': 'SR_B1', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'SR_B3', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'SR_B4', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'SR_B5', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'SR_B7', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'SR_ATMOS_OPACITY', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'SR_CLOUD_QA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_B6', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_ATRAN', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_CDIST', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_DRAD', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_EMIS', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_EMSD', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_QA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_TRAD', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'ST_URAD', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'QA_PIXEL', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}, {'id': 'QA_RADSAT', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7961, 7301], 'crs': 'EPSG:32613', 'crs_transform': [30, 0, 270285, 0, -30, 4414815]}], 'version': 1742849043334367, 'id': 'LANDSAT/LT05/C02/T1_L2/LT05_034033_20000913', 'properties': {'IMAGE_QUALITY': 9, 'WRS_TYPE': 2, 'CORRECTION_G ...
